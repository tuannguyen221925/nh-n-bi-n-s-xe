# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("duydieunguyen/licenseplates")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\khanh\.cache\kagglehub\datasets\duydieunguyen\licenseplates\1.archive...
# 100%|██████████| 959M/959M [00:40<00:00, 24.9MB/s]
# Extracting files...
# Path to dataset files: C:\Users\khanh\.cache\kagglehub\datasets\duydieunguyen\licenseplates\versions\1
